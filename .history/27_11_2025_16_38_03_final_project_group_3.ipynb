# %% [markdown]
# Group Project DSCI 100 Group 3
#
# Question:

# %% [markdown]
# Broad Question: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?
#
# Specific Question: How many hours does a player spend on the server based on their age, experience level, and gender?

# %% [markdown]
# url for the csv file "https://raw.githubusercontent.com/GSinghData/Convert-to-URL/refs/heads/main/players.csv"
